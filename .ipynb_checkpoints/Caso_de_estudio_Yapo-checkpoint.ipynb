# %% [markdown]
# Este notebook está vinculado al caso de estudio "Yapo" (ver el [documento](https://docs.google.com/document/d/1SwhwMOyG7-cmzasDeisQZ_NzX5v2VoZ7--lI4UhJz_U/edit#heading=h.5qaqs0frqkx4) de presentación). Se busca construir una base de datos de anuncios en Los Rios recopilando algunos anuncios de Yapo.cl.

# %% [markdown]
# # 1. Construcción de la base de datos

# %%
import mysql.connector 

db_connection = mysql.connector.connect(user="root",host="localhost",password=password)
cursor = db_connection.cursor()

# %%
cursor.execute("DROP DATABASE Yapo;")

# %%
cursor.execute("CREATE DATABASE Yapo;")
cursor.execute("USE Yapo")

#tabla vendedor
cursor.execute("CREATE TABLE vendedor ("+
               "nombre VARCHAR(100) PRIMARY KEY, ciudad VARCHAR(30), codigo_region VARCHAR(3), "+
               "nombre_region VARCHAR(30), "+
               "fecha_inscripcion DATE)")

#tabla anuncio
cursor.execute("CREATE TABLE anuncio (url VARCHAR(300) PRIMARY KEY, "+
               "titulo VARCHAR(200), descripcion MEDIUMTEXT, precio VARCHAR(30), categoria VARCHAR(50), "
               +"nombre VARCHAR(100), FOREIGN KEY (nombre) REFERENCES vendedor(nombre))")

# %% [markdown]
# # 2. Scrapping de datos para llenar nuestra base de datos Yapo

# %%
from urllib.request import urlopen as uReq
import urllib.request

from bs4 import BeautifulSoup as soup
from selenium import webdriver
import time

# %% [markdown]
# Con la librería Selenium, abriremos un navegador Chrome, en la página de los anuncios de Yapo en la región de Los Rios...

# %%
browser = webdriver.Chrome()
myUrl = 'https://www.yapo.cl/los_rios/todos_los_avisos?ca=11_s&l=0&w=1&cmn=243'
browser.get(myUrl)

# %% [markdown]
# Con la librería BeautifulSoup, realizamos un scrapping del código HTML para recuperar el enlace de la "última página"...

# %%
pageSoup = soup(browser.page_source, 'html.parser')

pages = pageSoup.find('span',  {'class', 'nohistory FloatRight'}).a['href']

# %%
pages
# Out:
# 'https://www.yapo.cl/los_rios?ca=11_s&cmn=243&o=655'

# %% [markdown]
# El parametro 'o' de la URL corresponde al número de la pagina en la lista de anuncios.

# %%
index = pages.rfind('=')
print(index)
lastPage = int(pages[index+1:])
print(lastPage)
root_pages = pages[:index+1]
print(root_pages)
# Out:
# 46
# 655
# https://www.yapo.cl/los_rios?ca=11_s&cmn=243&o=

# %% [markdown]
# - la variable "index" permite identificar el indice del último caracter '='.
#
# - la variable "lastPage" permite identificar el numero de la última página en la URL.
#
# - la variable "root_pages" permite aislar la cadena de caracteres que corresponde a la raiz de la URL (sin el numero de página).

# %% [markdown]
# Empezaremos la iteración sobre cada página que escrapear...

# %%
import datetime

def convert_date(yapo_date):
    month=yapo_date.split(" ")[0]
    year=yapo_date.split(" ")[1]
    
    convert = {'Enero' : 1,
            'Febrero' : 2,
            'Marzo' : 3,
            'Abril' : 4,
            'Mayo' : 5,
            'Junio' : 6,
            'Julio' : 7,
            'Agosto' : 8,
            'Septiembre' : 9, 
            'Octubre' : 10,
            'Noviembre' : 11,
            'Diciembre' : 12
           }
    
    
    new_date=datetime.date(int(year), convert[month], 1) 

    return new_date

print(convert_date("Febrero 2020"))
# Out:
# 2020-02-01

# %%
for i in range(lastPage):
    
    #recuperarmos la URL de la pagina corriente
    url = root_pages + str(i+1)
    
    #con Selenium, vamos en navegar en esta página
    browser.get(url)
    
    #empezamos el scrapping de la pagina corriente
    pageSoup = soup(browser.page_source, 'html.parser')
    
    #recuperamos todos los tags HTML que corresponden a la lista de anuncios en esta pagina
    links = pageSoup.findAll('td', {'class' : 'thumbs_subject'})
    
    #empezamos a iterar sobre cada anuncio
    for link in links:
        
        #todos los datos que necesitamos encontrar
        url, titulo, descripcion, precio, categoria="","","","",""
        nombre, ciudad, codigo_region, nombre_region, fecha_inscripcion="","","","",""
        
        #Navegamos hacia la pagina del anuncio
        url=link.find('a',{'class':'title'})['href']
        print(url)
        browser.get(link.find('a',{'class':'title'})['href'])
        
        
        #RECUPERAMOS EL TITULO DEL ANUNCIO           
        pageSoup = soup(browser.page_source, 'html.parser')
        if(pageSoup.find('h1', {"id" : "da_subject"})):
            titulo = pageSoup.find('h1', {"id" : "da_subject"}).text.strip()
            print(titulo)
            
        #RECUPERAMOS LA DESCRIPCION DEL ANUNCIO
        if(pageSoup.find('div', {"class" : "description"})):
            try:
                descripcion = pageSoup.find('div', {"class" : "description"}).text.split(' ', 1)[1].strip().replace(u'\n', u' ')
            except:
                continue
                
        #RECUPERAMOS EL PRECIO DEL ANUNCIO
        if(pageSoup.find('div', {"class" : "price text-right"})):
            precio = pageSoup.find('div', {"class" : "price text-right"}).text.strip().replace(u'\n', u' ').replace(u'\t', u'')
            print("precio:"+precio)
            
        #RECUPERAMOS LA CATEGORIA DEL ANUNCIO
        if(pageSoup.find('div', {"class" : "breadcrumbs"})):
            categoria = pageSoup.find('div', {"class" : "breadcrumbs"}).find('a', {"id" : "breadcrumb_category"}).find('strong').text.strip().replace(u'\n', u' ')
            print(categoria)
            
        
        #RECUPERAMOS EL NOMBRE DEL VENDEDOR, SU FECHA DE INSCRIPCION Y SU LOCALIDAD
        if(pageSoup.find('aside', {"class" : "sidebar-right"})):
            aside = pageSoup.find('aside', {"class" : "sidebar-right"})
    
            #print(aside.find('seller-info'))
            
            #NOMBRE
            nombre=aside.find('seller-info').attrs['username']
            
            #FECHA DE INSCRIPCION
            fecha_inscripcion_raw=aside.find('seller-info').attrs['seniority']
            try:
                fecha_inscripcion_raw=fecha_inscripcion_raw[len("En Yapo desde "):]
                fecha_inscripcion=convert_date(fecha_inscripcion_raw)
                print(fecha_inscripcion)
            except:
                fecha_inscripcion=None
                continue
                
            #LOCALIDAD
            localidad_raw=aside.find('seller-info').attrs['region']
            
            #print(localidad_raw)
            
            region_raw=localidad.split(",")[0]
            ciudad_raw=localidad.split(",")[1]
            
            codigo_region=region_raw.split(" ")[0]
            nombre_region=region_raw[len(codigo_region)+1:]
            ciudad=ciudad_raw[1:]
            
            print(codigo_region)
            print(nombre_region)
            print(ciudad)
         
        
        # LLENAMOS LA BASE DE DATOS: TABLA VENDEDOR
        
        try:
            sql = "INSERT INTO vendedor (nombre, ciudad, codigo_region, nombre_region, fecha_inscripcion) VALUES (%s, %s, %s,%s,%s)"
            val = (nombre, ciudad, codigo_region, nombre_region, fecha_inscripcion)
            cursor.execute(sql, val)
        except:
            continue
        
        # LLENAMOS LA BASE DE DATOS: TABLA ANUNCIO
        try:
            sql = "INSERT INTO anuncio (url, titulo, descripcion, precio, categoria) VALUES (%s, %s, %s,%s,%s)"
            val = (url, titulo, descripcion, precio, categoria)
            cursor.execute(sql, val)
        except:
            continue
        
        cursor.execute("COMMIT")
# Out:
# https://www.yapo.cl/los_rios/autos/suzuki_grand_nomade_73713726.htm?ca=11_s&first=1&oa=73713726&xsp=0
# Suzuki grand nomade
# precio:$ 3.800.000
# Autos, camionetas y 4x4
# 2015-04-01
# XIV
# Los Ríos
# Valdivia
# https://www.yapo.cl/los_rios/muebles/juego_de_living_3_sillones_73782294.htm?ca=11_s&oa=73782294&xsp=1
# Juego de living 3 sillones
# precio:$ 200.000
# Muebles
# 2018-01-01
# XIV
# Los Ríos
# Valdivia
# https://www.yapo.cl/los_rios/autos/toyota_tercel__73782287.htm?ca=11_s&oa=73782287&xsp=2
# Toyota tercel
# precio:$ 2.000.000
# Autos, camionetas y 4x4
# 2016-08-01
# XIV
# Los Ríos
# Valdivia
# https://www.yapo.cl/los_rios/moda-vestuario/calzas_moda_talla_l__73782253.htm?ca=11_s&oa=73782253&xsp=3
# Calzas moda talla L
# precio:$ 4.000
# Moda y vestuario
# https://www.yapo.cl/los_rios/autos/peugeot_205_1993_73782204.htm?ca=11_s&oa=73782204&xsp=4
# Peugeot 205 1993
# precio:$ 1.600.000
# Autos, camionetas y 4x4
# 2014-10-01
# XIV
# Los Ríos
# Valdivia
# https://www.yapo.cl/los_rios/celulares/samsung_a80_73782195.htm?ca=11_s&oa=73782195&xsp=5
# Samsung A80
# precio:$ 330.000
# Celulares, teléfonos y accesorios
# 2015-09-01
# XIV
# Los Ríos
# Valdivia
# https://www.yapo.cl/los_rios/muebles/rack_tv_para_led_73782161.htm?ca=11_s&oa=73782161&xsp=6
# Rack TV para LED
# precio:$ 20.000
# Muebles
# 2015-10-01
# XIV
# Los Ríos
# Valdivia
# https://www.yapo.cl/los_rios/consolas_videojuegos/busco_ps4_con_su_respectivo_joystick_73669457.htm?ca=11_s&oa=73669457&xsp=7
# Busco Ps4 con su respectivo joystick
# precio:$ 260.000
# Consolas, videojuegos y accesorios
# 2020-08-01
# XIV
# Los Ríos
# Valdivia
# https://www.yapo.cl/los_rios/moda-vestuario/chaqueta_mujer_talla_s_73782159.htm?ca=11_s&oa=73782159&xsp=8
# Chaqueta mujer talla S
# precio:$ 5.000
# Moda y vestuario
# https://www.yapo.cl/los_rios/autos/hynday_getz_1_3_73782128.htm?ca=11_s&oa=73782128&xsp=9
# Hynday getz 1.3
# precio:$ 2.500.000
# Autos, camionetas y 4x4
# 2018-08-01
# XIV
# Los Ríos
# Valdivia
# https://www.yapo.cl/los_rios/moda-vestuario/lindas_calzas_73782100.htm?ca=11_s&oa=73782100&xsp=10
# Lindas calzas
# precio:$ 4.000
# Moda y vestuario
# https://www.yapo.cl/los_rios/celulares/iphone_8__blanco__64_gb_73782068.htm?ca=11_s&oa=73782068&xsp=11
# IPhone 8 (Blanco) 64 GB
# precio:$ 340.000
# Celulares, teléfonos y accesorios
# 2016-06-01
# XIV
# Los Ríos
# Valdivia
# https://www.yapo.cl/los_rios/electrodomesticos/exprimidor_de_jugo_73782063.htm?ca=11_s&oa=73782063&xsp=12
# Exprimidor de jugo
# precio:$ 8.000
# Electrodomésticos
# 2015-08-01
# XIV
# Los Ríos
# Valdivia
# https://www.yapo.cl/los_rios/muebles/mesa_madera__su_fabricacion_se_mando_hacer__73782033.htm?ca=11_s&oa=73782033&xsp=13
# Mesa madera (su fabricación se mando hacer)
# precio:$ 100.000
# Muebles
# 2018-01-01
# XIV
# Los Ríos
# Valdivia
# https://www.yapo.cl/los_rios/celulares/iphone_8_73782014.htm?ca=11_s&oa=73782014&xsp=14
# Iphone 8
# Celulares, teléfonos y accesorios
# 2020-01-01
# XIV
# Los Ríos
# Valdivia
# https://www.yapo.cl/los_rios
# 2014-10-01
# XIV
# Los Ríos
# Valdivia
# https://www.yapo.cl/los_rios/instrumentos_musicales/teclado_piano__73780442.htm?ca=11_s&oa=73780442&xsp=1
# Teclado piano
# precio:$ 300.000
# Instrumentos musicales y accesorios
# 2014-06-01
# XIV
# Los Ríos
# Valdivia
# https://www.yapo.cl/los_rios/negocios_maquinaria_construccion/maestro_electrico_72795257.htm?ca=11_s&oa=72795257&xsp=2
# Maestro Electrico
# precio:$ 12.000
# Negocios, maquinaria y construcción
# 2019-03-01
# XIV
# Los Ríos
# Valdivia
# https://www.yapo.cl/los_rios/muebles/lavaplatos_mesa_redonda_73780369.htm?ca=11_s&oa=73780369&xsp=3
# Lavaplatos-Mesa redonda
# precio:$ 30.000
# Muebles
# 2015-06-01
# XIV
# Los Ríos
# Valdivia
# https://www.yapo.cl/los_rios/calzado/zapatillas_skechers_d__39_lite_73780307.htm?ca=11_s&oa=73780307&xsp=4
# Zapatillas skechers D'lite
# precio:$ 15.000
# Calzado
# 2019-09-01
# XIV
# Los Ríos
# Valdivia
# https://www.yapo.cl/los_rios/arrendar/departamento_town_house_isla_teja_73780291.htm?ca=11_s&oa=73780291&xsp=5
# departamento town house Isla Teja
# precio:$ 490.000
# Arriendo - Departamento
# 2017-08-01
# XIV
# Los Ríos
# Valdivia
# https://www.yapo.cl/los_rios/hobbies_outdoor/carretas_artesanas_73780262.htm?ca=11_s&oa=73780262&xsp=6
# Carretas artesanas
# precio:$ 8.000
# Hobbies y outdoor
# 2019-03-01
# XIV
# Los Ríos
# Valdivia
# https://www.yapo.cl/los_rios/consolas_videojuegos/destiny_edicion_legendaria_73780238.htm?ca=11_s&oa=73780238&xsp=7
# Destiny Edición Legendaria
# precio:$ 10.000
# Consolas, videojuegos y accesorios
# 2017-07-01
# XIV
# Los Ríos
# Valdivia
# https://www.yapo.cl/los_rios/computadores/compro_macbook_pro_73780221.htm?ca=11_s&oa=73780221&xsp=8
# Compro macbook pro
# Computadores y accesorios
# 2016-03-01
# XIV
# Los Ríos
# Valdivia
# https://www.yapo.cl/los_rios/moda-vestuario/blusa_tatienne_73779779.htm?ca=11_s&oa=73779779&xsp=9
# Blusa tatienne
# precio:$ 5.000
# Moda y vestuario
# 2019-10-01
# XIV
# Los Ríos
# Valdivia
# https://www.yapo.cl/los_rios/muebles/velador_madera_maciza_perfecto_estado_73779693.htm?ca=11_s&oa=73779693&xsp=10
# Velador madera maciza perfecto estado
# precio:$ 45.000
# Muebles
# 2019-01-01
# XIV
# Los Ríos
# Valdivia
# https://www.yapo.cl/los_rios/arte_antiguedades_colecciones/reloj_despertador_antiguo_73779673.htm?ca=11_s&oa=73779673&xsp=11
# Reloj despertador antiguo
# precio:$ 25.000
# Arte, antigüedades y colecciones
# 2016-05-01
# XIV
# Los Ríos
# Valdivia
# https://www.yapo.cl/los_rios/autos/chevrolet_corsa_extra_ml_1_6_73779571.htm?ca=11_s&oa=73779571&xsp=12
# Chevrolet Corsa extra ML 1.6
# precio:$ 900.000
# Autos, camionetas y 4x4
# 2017-11-01
# XIV
# Los Ríos
# Valdivia
# https://www.yapo.cl/los_rios/accesorios_vehiculos/balde_excavadora_72390582.htm?ca=11_s&oa=72390582&xsp=13
# Balde Excavadora
# precio:$ 2.200.000
# Accesorios y piezas para vehículos
# 2018-11-01
# XIV
# Los Ríos
# Valdivia
# https://www.yapo.cl/los_rios/barcos_lanchas_aviones/velero_yate_de_bahia_73779448.htm?ca=11_s&oa=73779448&xsp=14
# https://www.yapo.cl/los_rios/autos/alfa_romeo_giulietta1_4_2012_73779396.htm?ca=11_s&oa=73779396&xsp=15
# Alfa romeo giulietta1.4 2012
# precio:$ 6.500.000
# Autos, camionetas y 4x4
# 2014-10-01
# XIV
# Los Ríos
# Valdivia
# https://www.yapo.cl/los_rios/autos/suzuki_swift_2017_73779393.htm?ca=11_s&oa=73779393&xsp=16
# Suzuki swift 2017
# precio:$ 6.500.000
# Autos, camionetas y 4x4
# 2014-10-01
# XIV
# Los Ríos
# Valdivia
# https://www.yapo.cl/los_rios/autos/nissan_tiida_2011_73779391.htm?ca=11_s&oa=73779391&xsp=17
# Nissan tiida 2011
# precio:$ 3.700.000
# Autos, camionetas y 4x4
# 2014-10-01
# XIV
# Los Ríos
# Valdivia
# https://www.yapo.cl/los_rios/autos/volkswagen_gol_2013_73779323.htm?ca=11_s&oa=73779323&xsp=18
# Volkswagen gol 2013
# precio:$ 4.350.000
# Autos, camionetas y 4x4
# 2014-10-01
# XIV
# Los Ríos
# Valdivia
# https://www.yapo.cl/los_rios/autos/kia_motors_rio_2015_73779273.htm?ca=11_s&oa=73779273&xsp=19
# Kia motors rio 2015
# precio:$ 5.800.000
# Autos, camionetas y 4x4
# 2014-10-01
# XIV
# Los Ríos
# Valdivia
# https://www.yapo.cl/los_rios/comprar/casa_en_desarme_73779238.htm?ca=11_s&oa=73779238&xsp=20
# Casa en desarme
# precio:$ 1.500.000
# Vendo - Casa
# 2019-10-01
# XIV
# Los Ríos
# Valdivia
# https://www.yapo.cl/los_rios/servicios/regularizacion_de_viviendas__ley_del_mono_56525331.htm?ca=11_s&oa=56525331&xsp=21
# Regularización de viviendas, Ley del mono
# Servicios
# 2016-01-01
# XIV
# Los Ríos
# Valdivia
# https://www.yapo.cl/los_rios/autos/volvo_v40_d2_2017_73203603.htm?ca=11_s&oa=73203603&xsp=22
# Volvo v40 d2 2017
# precio:$ 12.200.000
# Autos, camionetas y 4x4
# 2017-05-01
# XIV
# Los Ríos
# Valdivia
# https://www.yapo.cl/los_rios/jardin_herramientas/accesorio_taladro_inalambrico_18_vol_makita_73779195.htm?ca=11_s&oa=73779195&xsp=23
# Accesorio Taladro inalambrico 18 Vol makita
# precio:$ 110.000
# Jardín, herramientas y exteriores
# https://www.yapo.cl/los_rios/jardin_herramientas/porton_1_70x2_73779114.htm?ca=11_s&oa=73779114&xsp=24
# Portón 1.70x2
# precio:$ 90.000
# Jardín, herramientas y exteriores
# 2015-03-01
# XIV
# Los Ríos
# Valdivia
# https://www.yapo.cl/los_rios/salud-belleza/compro_alisador_de_pelo__73779108.htm?ca=11_s&oa=73779108&xsp=25
# Compro alisador de pelo
# precio:$ 20.000
# Salud y belleza
# 2019-04-01
# XIV
# Los Ríos
# Valdivia
# https://www.yapo.cl/los_rios/coches-articulos-infantiles/repuestos_extractor_leche_73779066.htm?ca=11_s&oa=73779066&xsp=26
# Repuestos Extractor leche
# Coches y artículos infantiles
# 2016-04-01
# XIV
# Los Ríos
# Valdivia
# https://www.yapo.cl/los_rios/computadores/pantalla_17_pulgadas_hp_omen_17_w001la_73779059.htm?ca=11_s&oa=73779059&xsp=27
# Pantalla 17 Pulgadas Hp Omen 17-w001la
# precio:$ 100.000
# Computadores y accesorios
# 2013-12-01
# XIV
# Los Ríos
# Valdivia
# https://www.yapo.cl/los_rios/television_camaras/televisor_samsung_les_curvo_de_55_pulgadas_73778982.htm?ca=11_s&oa=73778982&xsp=28
# Televisor Samsung les curvo de 55 pulgadas
# Audio, TV, video y fotografía
# 2014-02-01
# XIV
# Los Ríos
# Valdivia
# https://www.yapo.cl/los_rios/arrendar/minidepartamento_amoblado_71505151.htm?ca=11_s&oa=71505151&xsp=29
# Minidepartamento amoblado
# precio:$ 195.000
# Arriendo - Departamento
# 2013-12-01
# XIV
# Los Ríos
# Valdivia
# https://www.yapo.cl/los_rios/arrendar/cabana_amoblada_x_mes_en_valdivia_69163517.htm?ca=11_s&oa=69163517&xsp=30
# Cabaña amoblada x mes en valdivia
# precio:$ 235.000
# Arriendo - Casa
# 2014-12-01
# XIV
# Los Ríos
# Valdivia
# https://www.yapo.cl/los_rios/autos/renault_clio_2019_73778851.htm?ca=11_s&oa=73778851&xsp=31
# Renault clio 2019
# precio:$ 7.600.000
# Autos, camionetas y 4x4
# 2014-07-01
# XIV
# Los Ríos
# Valdivia
# https://www.yapo.cl/los_rios/servicios/delivery_de_frutas_y_verduras_73778823.htm?ca=11_s&oa=73778823&xsp=32
# Delivery de frutas y verduras
# precio:$ 10.000
# Servicios
# 2016-12-01
# XIV
# Los Ríos
# Valdivia
# https://www.yapo.cl/los_rios/accesorios_vehiculos/caja_de_cambios_chevrolet_sail_2016_1_4_73778806.htm?ca=11_s&oa=73778806&xsp=33
# Caja de Cambios Chevrolet Sail 2016 1.4
# precio:$ 180.000
# Accesorios y piezas para vehículos
# 2013-11-01
# XIV
# Los Ríos
# Valdivia
# https://www.yapo.cl/los_rios/computadores/cooler_cpu_coolermaster_geminii_m4_de_bajo_perfil_73778790.htm?ca=11_s&oa=73778790&xsp=34
# Cooler CPU CoolerMaster Geminii M4 de bajo perfil
# precio:$ 30.000
# Computadores y accesorios
# 2013-12-01
# XIV
# Los Ríos
# Valdivia
# https://www.yapo.cl/los_rios/salud-belleza/perfume_100ml_73778767.htm?ca=11_s&oa=73778767&xsp=35
# Perfume 100ml
# precio:$ 35.000
# Salud y belleza
# 2015-09-01
# XIV
# Los Ríos
# Valdivia
# https://www.yapo.cl/los_rios/calzado/zapato_cat_mujer_73778730.htm?ca=11_s&oa=73778730&xsp=36
# Zapato cat mujer
# precio:$ 28.000
# Calzado
# 2017-04-01
# XIV
# Los Ríos
# Valdivia
# https://www.yapo.cl/los_rios/busco_empleo/disponibilidad_inmediata_ayudante_de_produccion_73778691.htm?ca=11_s&oa=73778691&xsp=37
# Disponibilidad inmediata ayudante de producción
# Busco empleo
# 2015-05-01
# XIV
# Los Ríos
# Valdivia
# https://www.yapo.cl/los_rios/computadores/acer_aspire_core_i3_6100u_8gb_128gb_ssd_m_2_750gb_73778665.htm?ca=11_s&oa=73778665&xsp=38
# Acer Aspire Core i3 6100U 8Gb 128Gb SSD m.2 750GB
# precio:$ 250.000
# Computadores y accesorios
# 2013-12-01
# XIV
# Los Ríos
# Valdivia
# https://www.yapo.cl/los_rios/calzado/taco_de_cuero_73778604.htm?ca=11_s&oa=73778604&xsp=39
# Taco de cuero
# precio:$ 5.000
# Calzado
# 2017-11-01
# XIV
# Los Ríos
# Valdivia
# https://www.yapo.cl/los_rios/calzado/merrel_nuevas_73778582.htm?ca=11_s&oa=73778582&xsp=40
# Merrel nuevas
# precio:$ 60.000
# Calzado
# 2015-04-01
# XIV
# Los Ríos
# Valdivia
# https://www.yapo.cl/los_rios/coches-articulos-infantiles/bolsas_ecologicas_lavables_73778566.htm?ca=11_s&oa=73778566&xsp=41
# Bolsas ecológicas lavables
# precio:$ 1.000
# Coches y artículos infantiles
# 2014-03-01
# XIV
# Los Ríos
# Valdivia
# https://www.yapo.cl/los_rios/arrendar/busco_parcela__73778557.htm?ca=11_s&oa=73778557&xsp=42
# Busco Parcela
# precio:$ 4.000.000
# Arriendo - Terreno
# 2016-11-01
# XIV
# Los Ríos
# Valdivia
# https://www.yapo.cl/los_rios/calzado/taco_fiesta_con_brillo_73778549.htm?ca=11_s&oa=73778549&xsp=43
# Taco fiesta con brillo
# precio:$ 10.000
# Calzado
# 2017-11-01
# XIV
# Los Ríos
# Valdivia
# https://www.yapo.cl/los_rios/autos/toyota_hilux_73778513.htm?ca=11_s&oa=73778513&xsp=44
# Toyota Hilux
# precio:$ 8.200.000
# Autos, camionetas y 4x4
# 2015-02-01
# XIV
# Los Ríos
# Valdivia
# https://www.yapo.cl/los_rios/muebles/lindo_mueble_estante_73778453.htm?ca=11_s&oa=73778453&xsp=45
# Lindo Mueble estante
# precio:$ 30.000
# Muebles
# 2016-09-01
# XIV
# Los Ríos
# Valdivia
# https://www.yapo.cl/los_rios/calzado/tacos_talla_35_73778452.htm?ca=11_s&oa=73778452&xsp=46
# Tacos talla 35
# precio:$ 10.000
# Calzado
# 2017-11-01
# XIV
# Los Ríos
# Valdivia
# https://www.yapo.cl/los_rios/arrendar/cabanas_regional_ano_corrido_72228304.htm?ca=11_s&oa=72228304&xsp=47
# Cabañas Regional Año Corrido
# precio:$ 320.000
# Arriendo - Casa
# 2014-09-01
# XIV
# Los Ríos
# Valdivia
# https://www.yapo.cl/los_rios/musica_peliculas/6_cd_s_pink_floyd___libro_graphic_tales_pink_floyd_73778352.htm?ca=11_s&oa=73778352&xsp=48
# 6 CD's Pink Floyd + libro Graphic Tales Pink Floyd
# precio:$ 30.000
# Música y películas (DVDs, etc.)
# 2019-01-01
# XIV
# Los Ríos
# Valdivia
# https://www.yapo.cl/los_rios/comprar/local_5__galeria_santiago_73778274.htm?ca=11_s&oa=73778274&xsp=49
# Local 5, Galeria Santiago
# precio:$ 95.000.000
# Vendo - Comercial e industrial
# 2016-07-01
# XIV
# Los Ríos
# Valdivia
# https://www.yapo.cl/los_rios/moda-vestuario/yeans_index_73778269.htm?ca=11_s&oa=73778269&xsp=0
# Yeans index
# precio:$ 5.000
# Moda y vestuario
# 2017-09-01
# XIV
# Los Ríos
# Valdivia
# https://www.yapo.cl/los_rios/comprar/terreno_cercano_a_uss_y_centro_73778228.htm?ca=11_s&oa=73778228&xsp=1
# Terreno Cercano a USS y Centro
# precio:$ 180.000.000
# Vendo - Terreno
# 2016-05-01
# XIV
# Los Ríos
# Valdivia
# https://www.yapo.cl/los_rios/moda-vestuario/bluzas_dama_sibilla_73778213.htm?ca=11_s&oa=73778213&xsp=2
# Bluzas dama sibilla
# precio:$ 15.000
# Moda y vestuario
# 2017-09-01
# XIV
# Los Ríos
# Valdivia
# https://www.yapo.cl/los_rios
09-01
# XIV
# Los Ríos
# Valdivia
# https://www.yapo.cl/los_rios/vestuario-futura-mama-ninos/gorrito_nino_black_and_blue_73777199.htm?ca=11_s&oa=73777199&xsp=21
# Gorrito niño black and blue
# precio:$ 5.000
# Vestuario futura mamá y niños
# 2017-09-01
# XIV
# Los Ríos
# Valdivia
# https://www.yapo.cl/los_rios/autos/kia_motors_optima_2019_como_nuevo_73591551.htm?ca=11_s&oa=73591551&xsp=22
# Kia motors optima 2019 como nuevo
# precio:$ 14.400.000
# Autos, camionetas y 4x4
# 2017-10-01
# XIV
# Los Ríos
# Valdivia
# https://www.yapo.cl/los_rios/autos/nissan_sentra_2011_73777117.htm?ca=11_s&oa=73777117&xsp=23
# Nissan sentra 2011
# precio:$ 4.450.000
# Autos, camionetas y 4x4
# 2014-10-01
# XIV
# Los Ríos
# Valdivia
# https://www.yapo.cl/los_rios/muebles/cama_de_2_plazas_buen_estado__73777042.htm?ca=11_s&oa=73777042&xsp=24
# Cama de 2 plazas buen estado
# Muebles
# 2019-07-01
# XIV
# Los Ríos
# Valdivia
# https://www.yapo.cl/los_rios/calzado/zapatos_cat_73776982.htm?ca=11_s&oa=73776982&xsp=25
# Zapatos cat
# precio:$ 15.000
# Calzado
# 2019-07-01
# XIV
# Los Ríos
# Valdivia
# https://www.yapo.cl/los_rios/autos/subaru_legacy_2_0r_73776887.htm?ca=11_s&oa=73776887&xsp=26
# Subaru legacy 2.0R
# precio:$ 4.500.000
# Autos, camionetas y 4x4
# 2020-07-01
# XIV
# Los Ríos
# Valdivia
# https://www.yapo.cl/los_rios/servicios/fletes_en_camioneta_73776869.htm?ca=11_s&oa=73776869&xsp=27
# Fletes en camioneta
# Servicios
# 2016-07-01
# XIV
# Los Ríos
# Valdivia
# https://www.yapo.cl/los_rios/accesorios_vehiculos/antivuelco_73776858.htm?ca=11_s&oa=73776858&xsp=28
# Antivuelco
# precio:$ 60.000
# Accesorios y piezas para vehículos
# 2017-09-01
# XIV
# Los Ríos
# Valdivia
# https://www.yapo.cl/los_rios/servicios/servicios_de_pintura__pintor_57728719.htm?ca=11_s&oa=57728719&xsp=29
# Servicios de pintura. Pintor
# precio:$ 1.000
# Servicios
# 2018-06-01
# XIV
# Los Ríos
# Valdivia
# https://www.yapo.cl/los_rios/celulares/samsung_s20__por_iphone_11_pro_max_73776752.htm?ca=11_s&oa=73776752&xsp=30
# Samsung s20+ por iPhone 11 pro max
# Celulares, teléfonos y accesorios
# 2014-10-01
# XIV
# Los Ríos
# Valdivia
# https://www.yapo.cl/los_rios/electrodomesticos/set_de_ralladores__73776642.htm?ca=11_s&oa=73776642&xsp=31
# Set de ralladores
# precio:$ 1.000
# Electrodomésticos
# 2018-09-01
# XIV
# Los Ríos
# Valdivia
# https://www.yapo.cl/los_rios/articulos-del-hogar/set_de_8_vasos_para_cafe__73776610.htm?ca=11_s&oa=73776610&xsp=32
# Set de 8 vasos para café
# precio:$ 4.000
# Otros artículos del hogar
# 2018-09-01
# XIV
# Los Ríos
# Valdivia
# https://www.yapo.cl/los_rios/television_camaras/necesito_mp3_reproductor_73776606.htm?ca=11_s&oa=73776606&xsp=33
# Necesito mp3 reproductor
# Audio, TV, video y fotografía
# 2019-11-01
# XIV
# Los Ríos
# Valdivia
# https://www.yapo.cl/los_rios/salud-belleza/aros_acero_inoxidable_con_sin_cruz_73776601.htm?ca=11_s&oa=73776601&xsp=34
# Aros acero inoxidable con/sin cruz
# precio:$ 5.000
# Salud y belleza
# 2016-12-01
# XIV
# Los Ríos
# Valdivia
# https://www.yapo.cl/los_rios/articulos-del-hogar/soporte_para_copas_nuevo__73776598.htm?ca=11_s&oa=73776598&xsp=35
# Soporte para copas nuevo
# precio:$ 1.500
# Otros artículos del hogar
# 2018-09-01
# XIV
# Los Ríos
# Valdivia
# https://www.yapo.cl/los_rios/negocios_maquinaria_construccion/set_botellas_de_vidrio__73776587.htm?ca=11_s&oa=73776587&xsp=36
# Set botellas de vidrio
# Negocios, maquinaria y construcción
# 2018-09-01
# XIV
# Los Ríos
# Valdivia
# https://www.yapo.cl/los_rios/articulos-del-hogar/organizador_de_condimentos__73776581.htm?ca=11_s&oa=73776581&xsp=37
# Organizador de condimentos
# precio:$ 4.000
# Otros artículos del hogar
# 2018-09-01
# XIV
# Los Ríos
# Valdivia
# https://www.yapo.cl/los_rios/bicicletas_ciclismo/funda_para_sillin_73776573.htm?ca=11_s&oa=73776573&xsp=38
# Funda para sillín
# precio:$ 8.000
# Bicicletas, ciclismo y accesorios
# 2020-03-01
# XIV
# Los Ríos
# Valdivia
# https://www.yapo.cl/los_rios/juguetes/scooter_73776566.htm?ca=11_s&oa=73776566&xsp=39
# Scooter
# precio:$ 10.000
# Juguetes
# 2015-12-01
# XIV
# Los Ríos
# Valdivia
# https://www.yapo.cl/los_rios/camiones_furgones/caio_712_m_benz_73325739.htm?ca=11_s&oa=73325739&xsp=40
# CAIO 712 M.Benz
# Buses, camiones y furgones
# 2014-09-01
# XIV
# Los Ríos
# Valdivia
# https://www.yapo.cl/los_rios/articulos-del-hogar/hermosos_monitos_agarra_cortimas_73776414.htm?ca=11_s&oa=73776414&xsp=41
# Hermosos monitos agarra cortimas
# precio:$ 5.000
# Otros artículos del hogar
# 2019-07-01
# XIV
# Los Ríos
# Valdivia
# https://www.yapo.cl/los_rios/autos/chevrolet_optra__72312466.htm?ca=11_s&oa=72312466&xsp=42
# Chevrolet optra
# precio:$ 3.500.000
# Autos, camionetas y 4x4
# 2015-01-01
# XIV
# Los Ríos
# Valdivia
# https://www.yapo.cl/los_rios/servicios/mudanzas_y_fletes_camion_cerrado_todo_chile_63295830.htm?ca=11_s&oa=63295830&xsp=43
# Mudanzas y Fletes Camión cerrado todo Chile
# Servicios
# 2014-08-01
# XIV
# Los Ríos
# Valdivia
# https://www.yapo.cl/los_rios/electrodomesticos/articulos_de_hogar_73775816.htm?ca=11_s&oa=73775816&xsp=44
# Articulos de hogar
# precio:$ 20.000
# Electrodomésticos
# 2015-09-01
# XIV
# Los Ríos
# Valdivia
# https://www.yapo.cl/los_rios/consolas_videojuegos/busco_play_3_con_2_controles___73775686.htm?ca=11_s&oa=73775686&xsp=45
# Busco play 3 con 2 controles.
# Consolas, videojuegos y accesorios
# 2016-04-01
# XIV
# Los Ríos
# Valdivia
# https://www.yapo.cl/los_rios/bolsos-bisuteria-accesorios/joyas_de_plata_925___73775674.htm?ca=11_s&oa=73775674&xsp=46
# Joyas de plata 925
# Bolsos, bisutería y accesorios
# 2017-04-01
# XIV
# Los Ríos
# Valdivia
# https://www.yapo.cl/los_rios/salud-belleza/delineadores_en_gel__crema__73775637.htm?ca=11_s&oa=73775637&xsp=47
# Delineadores en gel (crema)
# precio:$ 3.000
# Salud y belleza
# 2018-12-01
# XIV
# Los Ríos
# Valdivia
# https://www.yapo.cl/los_rios/negocios_maquinaria_construccion/plan_agua_pura__73775582.htm?ca=11_s&oa=73775582&xsp=48
# Plan agua pura
# precio:$ 12.000
# Negocios, maquinaria y construcción
# 2020-08-01
# XIV
# Los Ríos
# Valdivia
# https://www.yapo.cl/los_rios/autos/peugeot_208_2013_1_2_73775580.htm?ca=11_s&oa=73775580&xsp=49
# Peugeot 208 2013 1.2
# precio:$ 5.800.000
# Autos, camionetas y 4x4
# 2015-03-01
# XIV
# Los Ríos
# Valdivia
# https://www.yapo.cl/los_rios/arrendar/cabana_amueblada__73775576.htm?ca=11_s&oa=73775576&xsp=0
# cabaña amueblada
# precio:$ 160.000
# Arriendo - Casa
# 2017-06-01
# XIV
# Los Ríos
# Valdivia
# https://www.yapo.cl/los_rios/negocios_maquinaria_construccion/cortadora_de_cecinas_73775564.htm?ca=11_s&oa=73775564&xsp=1
# Cortadora de cecinas
# Negocios, maquinaria y construcción
# 2018-10-01
# XIV
# Los Ríos
# Valdivia
# https://www.yapo.cl/los_rios/moda-vestuario/ropa_mujer_talla_s_73775559.htm?ca=11_s&oa=73775559&xsp=2

# %% [markdown]
# # 3. Consultas SQL
#
# - ¿Cuál es el precio promedio de los anuncios por categoría?
#
# - ¿Cuál es el número de anuncios por vendedor y por día?
#
# - ¿Insertar una columna “Perfil” en la tabla Vendedor. Los Vendedores que publicaron más de 5 anuncios en los últimos 7 días, tienen un perfil “Pro”, los otros se consideran “Personal”.
#
# - ¿Cuál es el precio promedio de los anuncios según el día de la semana (lunes, martes, miercoles, etc.)

# %%
#¿Cuál es el precio promedio de los anuncios por categoría?
