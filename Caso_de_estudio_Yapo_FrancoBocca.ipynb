# %% [markdown]
# Este notebook está vinculado al caso de estudio "Yapo" (ver el [documento](https://docs.google.com/document/d/1SwhwMOyG7-cmzasDeisQZ_NzX5v2VoZ7--lI4UhJz_U/edit#heading=h.5qaqs0frqkx4) de presentación). Se busca construir una base de datos de anuncios en Los Rios recopilando algunos anuncios de Yapo.cl.
#
# ### Mi trabajo en este notebook se construyó en base a lo aportado en clases por el profesor, usando la base de datos provista en el github, debido a que tengo un plan limitado de internet en estos momentos, lo que no me permitió crear una base de datos propia con los anuncios de yapo.

# %% [markdown]
# # 1. Construcción de la base de datos

# %%
import mysql.connector 

#La contraseña de mi base de datos no es root

db_connection = mysql.connector.connect(user="root",host="localhost",password="1492sole+@LUCKY") 
cursor = db_connection.cursor()

# %%
#cursor.execute("DROP DATABASE Yapo2;") cuidado al ejecutar esta linea

# %%
#cursor.execute("CREATE DATABASE Yapo2;")
#cursor.execute("USE Yapo2")

##tabla vendedor
#cursor.execute("CREATE TABLE vendedor ("+
#               "id_vendedor VARCHAR(130) PRIMARY KEY, nombre VARCHAR(100), ciudad VARCHAR(30), codigo_region VARCHAR(7), "+
#               "nombre_region VARCHAR(30), "+
#               "fecha_inscripcion DATE)")
#
##tabla anuncio
#cursor.execute("CREATE TABLE anuncio (url VARCHAR(300) PRIMARY KEY, "+
#               "titulo VARCHAR(200), descripcion MEDIUMTEXT, precio INT, moneda VARCHAR(2), fecha_publicacion DATE, categoria VARCHAR(50), "
#               +"id_vendedor VARCHAR(130), FOREIGN KEY (id_vendedor) REFERENCES vendedor(id_vendedor))")

# %% [markdown]
# # 2. Scrapping de datos para llenar nuestra base de datos Yapo

# %%
from urllib.request import urlopen as uReq
import urllib.request

from bs4 import BeautifulSoup as soup
from selenium import webdriver
import time

# %% [markdown]
# Con la librería Selenium, abriremos un navegador Chrome, en la página de los anuncios de Yapo en la región de Los Rios... __(UPDATE: todo chile)__
#
# **En mi experiencia personal tuve problemas usando el webdriver (problemas con el PATH), pero encontré una solución a mi problema al usar webdriver-manager, el cual de forma automática configura el path.**

# %%
# !pip install webdriver-manager
from webdriver_manager.chrome import ChromeDriverManager


browser = webdriver.Chrome(ChromeDriverManager().install())
#browser = webdriver.Chrome()

myUrl = 'https://www.yapo.cl/chile/todos_los_avisos?ca=12_s&l=0'
#myUrl = 'https://www.yapo.cl/los_rios/todos_los_avisos?ca=11_s&l=0&w=1&cmn=243'
browser.get(myUrl)
# Out:
# ...
# [WDM] - Current google-chrome version is 84.0.4147
# [WDM] - Get LATEST driver version for 84.0.4147
# [WDM] - Get LATEST driver version for 84.0.4147
# [WDM] - Trying to download new driver from http://chromedriver.storage.googleapis.com/84.0.4147.30/chromedriver_linux64.zip
# [WDM] - Driver has been saved in cache [/home/gma950/.wdm/drivers/chromedriver/linux64/84.0.4147.30]

# %% [markdown]
# Con la librería BeautifulSoup, realizamos un scrapping del código HTML para recuperar el enlace de la "última página"...

# %%
pageSoup = soup(browser.page_source, 'html.parser')

pages = pageSoup.find('span',  {'class', 'nohistory FloatRight'}).a['href']

# %%
pages
# Out:
# 'https://www.yapo.cl/chile?ca=12_s&o=28199'

# %% [markdown]
# El parametro 'o' de la URL corresponde al número de la pagina en la lista de anuncios.

# %%
index = pages.rfind('=')
print(index)
lastPage = int(pages[index+1:])
print(lastPage)
root_pages = pages[:index+1]
print(root_pages)
# Out:
# 35
# 28199
# https://www.yapo.cl/chile?ca=12_s&o=

# %% [markdown]
# - la variable "index" permite identificar el indice del último caracter '='.
#
# - la variable "lastPage" permite identificar el numero de la última página en la URL.
#
# - la variable "root_pages" permite aislar la cadena de caracteres que corresponde a la raiz de la URL (sin el numero de página).

# %% [markdown]
# Empezaremos la iteración sobre cada página que escrapear...
#
# **El scraping se ha mantendido intacto**

# %%
import datetime

def convert_date(yapo_date):
    month=yapo_date.split(" ")[0]
    year=yapo_date.split(" ")[1]
    
    convert = {'Enero' : 1,
            'Febrero' : 2,
            'Marzo' : 3,
            'Abril' : 4,
            'Mayo' : 5,
            'Junio' : 6,
            'Julio' : 7,
            'Agosto' : 8,
            'Septiembre' : 9, 
            'Octubre' : 10,
            'Noviembre' : 11,
            'Diciembre' : 12
           }
    
    
    new_date=datetime.date(int(year), convert[month], 1) 

    return new_date

print(convert_date("Febrero 2020"))
# Out:
# 2020-02-01

# %%
for i in range(lastPage):
    
    #recuperarmos la URL de la pagina corriente
    url = root_pages + str(i+1)
    
    #con Selenium, vamos en navegar en esta página
    browser.get(url)
    
    #empezamos el scrapping de la pagina corriente
    pageSoup = soup(browser.page_source, 'html.parser')
    
    #recuperamos todos los tags HTML que corresponden a la lista de anuncios en esta pagina
    links = pageSoup.findAll('td', {'class' : 'thumbs_subject'})
    
    #empezamos a iterar sobre cada anuncio
    for link in links:
        
        #todos los datos que necesitamos encontrar
        url, titulo, descripcion, precio, fecha_publicacion, categoria="","","",None,"", ""
        nombre, ciudad, codigo_region, nombre_region, fecha_inscripcion="","","","",""
        
        #Navegamos hacia la pagina del anuncio
        url=link.find('a',{'class':'title'})['href']
        print(url)
        browser.get(link.find('a',{'class':'title'})['href'])

        #RECUPERAMOS LA FECHA DE PUBLICACION DEL ANUNCIO          
        pageSoup = soup(browser.page_source, 'html.parser')
        if(pageSoup.find('time')):
            datetime_raw = pageSoup.find('time').attrs['datetime']
            date_publication_raw=datetime_raw.split("T")[0]
            date_publication_raw=  date_publication_raw.split("-")
            
            date_publication=datetime.date(int(date_publication_raw[0]), int(date_publication_raw[1]),
                                           int(date_publication_raw[2]))
            print("datetime:")
            print(date_publication)
        
        #RECUPERAMOS EL TITULO DEL ANUNCIO           
        pageSoup = soup(browser.page_source, 'html.parser')
        if(pageSoup.find('h1', {"id" : "da_subject"})):
            titulo = pageSoup.find('h1', {"id" : "da_subject"}).text.strip()
            print(titulo)
            
        #RECUPERAMOS LA DESCRIPCION DEL ANUNCIO
        if(pageSoup.find('div', {"class" : "description"})):
            try:
                descripcion = pageSoup.find('div', {"class" : "description"}).text.split(' ', 1)[1].strip().replace(u'\n', u' ')
            except:
                continue
                
        #RECUPERAMOS EL PRECIO DEL ANUNCIO
        if(pageSoup.find('div', {"class" : "price text-right"})):
            precio_raw = pageSoup.find('div', {"class" : "price text-right"}).text.strip().replace(u'\n', u' ').replace(u'\t', u'')
            precio_raw = precio_raw.split(" ")
            moneda = precio_raw[0]
            precio = precio_raw[1].split(",")[0].replace(u'.', u'')
            print("precio:"+precio)
            
        #RECUPERAMOS LA CATEGORIA DEL ANUNCIO
        if(pageSoup.find('div', {"class" : "breadcrumbs"})):
            categoria = pageSoup.find('div', {"class" : "breadcrumbs"}).find('a', {"id" : "breadcrumb_category"}).find('strong').text.strip().replace(u'\n', u' ')
            print(categoria)
            
        
        #RECUPERAMOS EL NOMBRE DEL VENDEDOR, SU FECHA DE INSCRIPCION Y SU LOCALIDAD
        if(pageSoup.find('aside', {"class" : "sidebar-right"})):
            aside = pageSoup.find('aside', {"class" : "sidebar-right"})
    
            #print(aside.find('seller-info'))
            
            #NOMBRE
            if(aside.find('seller-info')!=None):
                nombre=aside.find('seller-info').attrs['username']
            
                #FECHA DE INSCRIPCION
                fecha_inscripcion_raw=aside.find('seller-info').attrs['seniority']
                try:
                    fecha_inscripcion_raw=fecha_inscripcion_raw[len("En Yapo desde "):]
                    fecha_inscripcion=convert_date(fecha_inscripcion_raw)
                    print(fecha_inscripcion)
                except:
                    fecha_inscripcion=None
                    continue
                
                #LOCALIDAD
                localidad_raw=aside.find('seller-info').attrs['region']
            
                #print(localidad_raw)
            
                region_raw=localidad_raw.split(",")[0]
                ciudad_raw=localidad_raw.split(",")[1]
            
                codigo_region=region_raw.split(" ")[0]
                nombre_region=region_raw[len(codigo_region)+1:]
                ciudad=ciudad_raw[1:]
                
        # LLENAMOS LA BASE DE DATOS: TABLA VENDEDOR
        
        try:
            sql = "INSERT INTO vendedor (id_vendedor,nombre, ciudad, codigo_region, nombre_region, fecha_inscripcion) VALUES (%s,%s, %s, %s,%s,%s)"
            val = (nombre+"_"+codigo_region+"_"+ciudad,nombre, ciudad, codigo_region, nombre_region, fecha_inscripcion)
            cursor.execute(sql, val)
        except Exception as e1:
            print(e1)
            #continue
        
        # LLENAMOS LA BASE DE DATOS: TABLA ANUNCIO
        try:
            sql = "INSERT INTO anuncio (url, titulo, descripcion, precio, moneda, fecha_publicacion, categoria, id_vendedor) VALUES (%s, %s, %s,%s, %s, %s, %s, %s)"
            val = (url, titulo, descripcion, int(precio), moneda, date_publication, categoria, nombre+"_"+codigo_region+"_"+ciudad)
            cursor.execute(sql, val)
        except Exception as e2:
            print(e2)
            #continue
        
        cursor.execute("COMMIT")
# Out:
# https://www.yapo.cl/region_metropolitana/moda-vestuario/chaqueta_cuero_unisex_73859055.htm?ca=15_s&first=1&oa=73859055&xsp=0
# datetime:
# 2020-08-19
# Chaqueta cuero unisex
# precio:20000
# Moda y vestuario
# 2014-09-01
# https://www.yapo.cl/ohiggins/ofertas_de_empleo/asistente_informatica_73859054.htm?ca=7_s&oa=73859054&xsp=1
# datetime:
# 2020-08-19
# Asistente Informática
# precio:500000
# Ofertas de empleo
# 2017-02-01
# https://www.yapo.cl/magallanes_antartica/salud-belleza/compro_ensure_advance_y_glucerna_73859053.htm?ca=14_s&oa=73859053&xsp=2
# datetime:
# 2020-08-19
# Compro Ensure advance y glucerna
# Salud y belleza
# 2014-11-01
# int() argument must be a string, a bytes-like object or a number, not 'NoneType'
# https://www.yapo.cl/region_metropolitana/accesorios_vehiculos/moldura_chevrolet_spark_lt_73859052.htm?ca=15_s&oa=73859052&xsp=3
# datetime:
# 2020-08-19
# Moldura chevrolet spark lt
# precio:15000
# Accesorios y piezas para vehículos
# 2015-08-01
# ...

# %%
# !pip install pyshp

# %%
import numpy as np
import pandas as pd
import shapefile as shp
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime
from pandas import DataFrame
import pandas as pd

sns.set(style="whitegrid", palette="pastel", color_codes=True)
sns.mpl.rc("figure", figsize=(12,6))

# %%javascript
IPython.OutputArea.auto_scroll_threshold = 9999;
# Out:
# UsageError: Line magic function `%%javascript` not found.

# %%
import mysql.connector 

db_connection = mysql.connector.connect(user="root",host="localhost",password="1492sole+@LUCKY")
cursor = db_connection.cursor()

cursor.execute("use Yapo2")

# %%
#¿Cuál es el precio promedio de los anuncios por categoría?


sql = "SELECT categoria, avg(precio) FROM anuncio WHERE moneda=\"$\" GROUP BY categoria ORDER BY avg(precio) DESC;"
cursor.execute(sql)
df1 = DataFrame(cursor.fetchall())
df1.columns = cursor.column_names
df1
# Out:
#                                     categoria     avg(precio)
# 0              Vendo - Comercial e industrial  222632000.0000
# 1                             Vendo - Oficina  111333333.3333
# 2                                Vendo - Casa  101286759.7493
# 3                             Vendo - Terreno   64879135.6972
# 4                        Vendo - Departamento   63364095.8938
# 5                  Buses, camiones y furgones   11299310.3448
# 6                     Autos, camionetas y 4x4    6434454.9255
# 7                             Otros vehículos    5322276.4894
# 8                          Arriendo - Terreno    4000000.0000
# 9                   Barcos, lanchas y aviones    3433000.0000
# 10                                      Motos    2709577.0335
# 11                            Arriendo - Casa    2039979.6798
# 12     Vendo - Estacionamiento, bodega u otro    1757545.4545
# 13        Negocios, maquinaria y construcción    1394903.2460
# ...

# %%
#¿Cuál es el número de anuncios por vendedor?

sql = "SELECT id_vendedor, nombre, count(*) as_nb_anuncios FROM anuncio JOIN vendedor USING (id_vendedor)  GROUP BY id_vendedor, nombre ORDER BY count(*) DESC;"
cursor.execute(sql)
df1 = DataFrame(cursor.fetchall())
df1.columns = cursor.column_names
df1
# Out:
#                                             id_vendedor  \
# 0               Desarmaduria Autorey_Región_La Cisterna
# 1                    Carolina fernandez_Región_Santiago
# 2                        Alberto ojeda_XII_Punta Arenas
# 3                   desarmaduriaterracars_Región_Colina
# 4     Ceballos & Jopia Gestión Inmobiliaria SpA_V_Vi...
# ...                                                 ...
# 6693                             José Esteban_IX_Temuco
# 6694            Jose Fabian Torres Luna_Región_Santiago
# 6695                        Jose Lagos_Región_Peñalolén
# 6696                        José luis soto_V_Valparaíso
# 6697                     josé mansilla_XII_Punta Arenas
#
#                                          nombre  as_nb_anuncios
# 0                          Desarmaduria Autorey             559
# 1                            Carolina fernandez             410
# 2                                 Alberto ojeda             321
# ...

# %%
#¿Cuál es el precio promedio de los anuncios según el día de la semana (lunes, martes, miercoles, etc.), por categoria?
sql = "select DAYOFWEEK(fecha_publicacion) as dia,categoria, avg(precio) from anuncio where moneda=\"$\" group by dia, categoria order by avg(precio) desc;"
cursor.execute(sql)
df1 = DataFrame(cursor.fetchall())
df1.columns = cursor.column_names
df1
# Out:
#     dia                       categoria     avg(precio)
# 0     3  Vendo - Comercial e industrial  260790000.0000
# 1     4                 Vendo - Oficina  180000000.0000
# 2     3                    Vendo - Casa  104975976.9018
# 3     4                 Vendo - Terreno   93943243.2432
# 4     4                    Vendo - Casa   81012389.3805
# ..  ...                             ...             ...
# 92    3   Vestuario futura mamá y niños      17971.1765
# 93    3               Libros y revistas      12982.3787
# 94    4                 Otros productos      12676.0377
# 95    4               Libros y revistas      10749.8529
# 96    4   Vestuario futura mamá y niños       5796.6102
#
# [97 rows x 3 columns]

# %%
#Insertar Columna Perfil en la tabla vendedor
#Vendedor con mas de 5 publicaciones = Pro
#Vendedor con menos de 5 publicaciones = Personal

#sql = "ALTER TABLE vendedor ADD perfil VARCHAR(10);"
#cursor.execute(sql)



#sql = "UPDATE vendedor SET perfil=\"Personal\";"
#cursor.execute(sql)
#cursor.execute("COMMIT")

#sql = "SELECT id_vendedor FROM anuncio JOIN vendedor USING (id_vendedor)  GROUP BY id_vendedor HAVING count(*) >= 5 ORDER BY count(*) DESC;"
#cursor.execute(sql)
#df1 = DataFrame(cursor.fetchall())
#df1.columns = cursor.column_names
#print(df1[:5])

#for index,row in df1.iterrows():
#    id_vendedor=row[0]
    
#    sql = "UPDATE vendedor SET perfil=\"Pro\" WHERE id_vendedor=\""+id_vendedor+"\";"
#    cursor.execute(sql)

#cursor.execute("COMMIT")

# %%
#¿Cuál es el número de vendedores por tipo de perfil?
sql = "SELECT perfil, count(*) as vendedores FROM vendedor GROUP BY perfil;"
cursor.execute(sql)
df1 = DataFrame(cursor.fetchall())
df1.columns = cursor.column_names
df1
# Out:
#      perfil  vendedores
# 0  Personal        6813
# 1       Pro        1044

# %% [markdown]
# ### Primero Seteamos el Mapa para las visualizaciones

# %%
shp_path = "./cl_regiones_geo/cl_regiones_geo.shp"
sf = shp.Reader(shp_path, encoding="ISO8859-1")
def read_shapefile(sf):
    """
    Read a shapefile into a Pandas dataframe with a 'coords' 
    column holding the geometry information. This uses the pyshp
    package
    """
    fields = [x[0] for x in sf.fields][1:]
    records = sf.records()
    shps = [s.points for s in sf.shapes()]
    df = pd.DataFrame(columns=fields, data=records)
    df = df.assign(coords=shps)
    return df

# %%
df = read_shapefile(sf)
df.shape
# Out:
# (15, 3)

# %%
def calc_color(data, color=None):
        if color   == 1: 
            color_sq =  ['#dadaebFF','#bcbddcF0','#9e9ac8F0',
                        '#807dbaF0','#6a51a3F0','#54278fF0']; 
            colors = 'Purples';
        elif color == 2: 
            color_sq = ['#c7e9b4','#7fcdbb','#41b6c4',
                        '#1d91c0','#225ea8','#253494']; 
            colors = 'YlGnBu';
        elif color == 3: 
            color_sq = ['#f7f7f7','#d9d9d9','#bdbdbd',
                        '#969696','#636363','#252525']; 
            colors = 'Greys';
        elif color == 9: 
            color_sq = ['#ff0000','#ff0000','#ff0000',
                        '#ff0000','#ff0000','#ff0000']
        else:            
            color_sq = ['#ffffd4','#fee391','#fec44f',
                        '#fe9929','#d95f0e','#993404']; 
            colors = 'YlOrBr';
        
        new_data, bins = pd.qcut(data, 6, retbins=True, labels=list(range(6)))
        color_ton = []
        for val in new_data:
            color_ton.append(color_sq[val]) 
        if color != 9:
            colors = sns.color_palette(colors, n_colors=6)
            sns.palplot(colors, 0.6);
            for i in range(6):
                print ("\n"+str(i+1)+': '+str(int(bins[i]))+
                       " => "+str(int(bins[i+1])-1), end =" ")
            print("\n\n   1   2   3   4   5   6")    
        return color_ton, bins;

# %%
def plot_regiones_data(sf, title, regiones, data=None, 
                      color=None, print_id=False):
    '''
    Plot map with selected comunes, using specific color
    '''
    
    color_ton, bins = calc_color(data, color)
    df = read_shapefile(sf)
    region_id = []
    for i in regiones:
        #print(i)
        id = df[df.NOMBRE == i].index.values[0]
        #id = df[df.NOMBRE == i].index.get_values()[0]
        region_id.append(id)
        
        
    y_lim = (-42,-17) # latitude 
    x_lim = (-76, -66) # longitude
    
    plot_map_fill_multiples_ids_tone(sf, title, region_id, 
                                     print_id, 
                                     color_ton, 
                                     bins, 
                                     x_lim = x_lim, 
                                     y_lim = y_lim, 
                                     figsize = (10,25));

# %%
def plot_map_fill_multiples_ids_tone(sf, title, comuna,  
                                     print_id, color_ton, 
                                     bins, 
                                     x_lim = None, 
                                     y_lim = None, 
                                     figsize = (5,12)):
    '''
    Plot map with lim coordinates
    '''
        
    plt.figure(figsize = figsize)
    fig, ax = plt.subplots(figsize = figsize)
    fig.suptitle(title, fontsize=16)
    for shape in sf.shapeRecords():
        x = [i[0] for i in shape.shape.points[:]]
        y = [i[1] for i in shape.shape.points[:]]
        ax.plot(x, y, 'k')
            
    for id in comuna:
        shape_ex = sf.shape(id)
        x_lon = np.zeros((len(shape_ex.points),1))
        y_lat = np.zeros((len(shape_ex.points),1))
        for ip in range(len(shape_ex.points)):
            x_lon[ip] = shape_ex.points[ip][0]
            y_lat[ip] = shape_ex.points[ip][1]
        ax.fill(x_lon,y_lat, color_ton[comuna.index(id)])
        if print_id != False:
            x0 = np.mean(x_lon)
            y0 = np.mean(y_lat)
            plt.text(x0, y0, id, fontsize=10)
    if (x_lim != None) & (y_lim != None):     
        plt.xlim(x_lim)
        plt.ylim(y_lim)

# %%
from pandas import DataFrame
#¿Cuál es el número de anuncios Yapo.cl en cada región de Chile ?

sql = "select nombre_region, count(*) as nb_anuncios from vendedor join anuncio using (id_vendedor) where nombre_region != \"Ñuble\" group by nombre_region order by nb_anuncios DESC;"
cursor.execute(sql)
df1 = DataFrame(cursor.fetchall())
df1.columns = cursor.column_names
df1
# Out:
#              nombre_region  nb_anuncios
# 0            Metropolitana        11942
# 1                   Biobío         1985
# 2               Valparaíso         1783
# 3                Los Lagos         1332
# 4                Araucanía         1118
# 5   Magallanes & Antártica         1051
# 6                 Coquimbo         1010
# 7                O'Higgins          864
# 8              Antofagasta          855
# 9                    Maule          836
# 10                Los Ríos          668
# 11                Tarapacá          310
# 12      Arica & Parinacota          272
# 13                 Atacama          169
# 14                   Aisén          159

# %%
read_shapefile(sf).head(15)
# Out:
#    ID_2002                                   NOMBRE  \
# 0       15                       Arica y Parinacota
# 1       01                                 Tarapaca
# 2       02                              Antofagasta
# 3       03                                  Atacama
# 4       04                                 Coquimbo
# 5       05                               Valparaiso
# 6       13                Metropolitana de Santiago
# 7       06      Libertador Gral. Bernardo O'Higgins
# 8       07                                    Maule
# 9       08                                   Biobio
# 10      09                             La Araucania
# 11      14                                 Los Rios
# 12      10                                Los Lagos
# 13      11  Aisen del Gral. Carlos Ibañez del Campo
# 14      12     Magallanes y de la Antartica Chileno
#
#                                                coords
# 0   [(-70.266233, -19.190222), (-70.27196, -19.188...
# ...

# %%
df1.loc[df1.nombre_region == "Metropolitana", "nombre_region"] = "Metropolitana de Santiago"
df1.loc[df1.nombre_region == "Valparaíso", "nombre_region"] = "Valparaiso"
df1.loc[df1.nombre_region == "Biobío", "nombre_region"] = "Biobio"
df1.loc[df1.nombre_region == "Magallanes & Antártica", "nombre_region"] = "Magallanes y de la Antartica Chileno"
df1.loc[df1.nombre_region == "Araucanía", "nombre_region"] = "La Araucania"
df1.loc[df1.nombre_region == "O'Higgins", "nombre_region"] = "Libertador Gral. Bernardo O'Higgins"
df1.loc[df1.nombre_region == "Los Ríos", "nombre_region"] = "Los Rios"
df1.loc[df1.nombre_region == "Tarapacá", "nombre_region"] = "Tarapaca"
df1.loc[df1.nombre_region == "Aisén", "nombre_region"] = "Aisen del Gral. Carlos Ibañez del Campo"
df1.loc[df1.nombre_region == "Arica & Parinacota", "nombre_region"] = "Arica y Parinacota"

# %%
# %%javascript
# IPython.OutputArea.auto_scroll_threshold = 9999;

# %%
data = df1.nb_anuncios
regiones = df1.nombre_region

print_id = False # The shape id will be printed
color_pallete = 1 # 'Purples'
plot_regiones_data(sf, 'Número de anuncios Yapo.cl por regiones', regiones, data, color_pallete, print_id)
# Out:
# 1: 159 => 283
# 2: 284 => 778
# 3: 779 => 863
# 4: 864 => 1072
# 5: 1073 => 1631
# 6: 1632 => 11941
#
#    1   2   3   4   5   6

# %% [markdown]
# ### ¿Cuál es el precio promedio de los vehíclos en venta en cada región?

# %%
sql = "select nombre_region, avg(precio) as precio_prom from vendedor join anuncio using (id_vendedor) where categoria=\"Autos, camionetas y 4x4\" and moneda=\"$\" and nombre_region != \"Ñuble\" and precio > 100000 group by nombre_region order by precio_prom DESC;"
#sql = "select nombre_region, avg(precio) as precio_prom from vendedor join anuncio using (id_vendedor) where categoria=\"Arriendo - Departamento\" and moneda=\"$\" and nombre_region != \"Ñuble\" and precio < 1500000 group by nombre_region order by precio_prom DESC;"
cursor.execute(sql)
df1 = DataFrame(cursor.fetchall())
df1.columns = cursor.column_names
df1
# Out:
# select nombre_region, avg(precio) as precio_prom from vendedor join anuncio using (id_vendedor) where categoria="Autos, camionetas y 4x4" and moneda="$" and nombre_region != "Ñuble" and precio > 100000 group by nombre_region order by precio_prom DESC;
#              nombre_region   precio_prom
# 0            Metropolitana  7935107.7844
# 1                Araucanía  6788149.7797
# 2               Valparaíso  6714687.5000
# 3                 Los Ríos  6645774.6479
# 4   Magallanes & Antártica  6608490.5660
# 5              Antofagasta  6589551.0204
# 6                O'Higgins  5919774.4361
# 7                   Biobío  5788005.4348
# 8                Los Lagos  5615220.5882
# 9                    Aisén  5613636.3636
# 10                Coquimbo  5242105.2632
# 11                   Maule  4847155.9633
# 12                Tarapacá  4070634.9206
# 13                 Atacama  3940000.0000
# 14      Arica & Parinacota  2964864.8649

# %%
df1["precio_prom"] = df1["precio_prom"].astype(int)
df1
# Out:
#              nombre_region  precio_prom
# 0            Metropolitana      7935107
# 1                Araucanía      6788149
# 2               Valparaíso      6714687
# 3                 Los Ríos      6645774
# 4   Magallanes & Antártica      6608490
# 5              Antofagasta      6589551
# 6                O'Higgins      5919774
# 7                   Biobío      5788005
# 8                Los Lagos      5615220
# 9                    Aisén      5613636
# 10                Coquimbo      5242105
# 11                   Maule      4847155
# 12                Tarapacá      4070634
# 13                 Atacama      3940000
# 14      Arica & Parinacota      2964864

# %%
df1.loc[df1.nombre_region == "Metropolitana", "nombre_region"] = "Metropolitana de Santiago"
df1.loc[df1.nombre_region == "Valparaíso", "nombre_region"] = "Valparaiso"
df1.loc[df1.nombre_region == "Biobío", "nombre_region"] = "Biobio"
df1.loc[df1.nombre_region == "Magallanes & Antártica", "nombre_region"] = "Magallanes y de la Antartica Chileno"
df1.loc[df1.nombre_region == "Araucanía", "nombre_region"] = "La Araucania"
df1.loc[df1.nombre_region == "O'Higgins", "nombre_region"] = "Libertador Gral. Bernardo O'Higgins"
df1.loc[df1.nombre_region == "Los Ríos", "nombre_region"] = "Los Rios"
df1.loc[df1.nombre_region == "Tarapacá", "nombre_region"] = "Tarapaca"
df1.loc[df1.nombre_region == "Aisén", "nombre_region"] = "Aisen del Gral. Carlos Ibañez del Campo"
df1.loc[df1.nombre_region == "Arica & Parinacota", "nombre_region"] = "Arica y Parinacota"

# %%
data = df1.precio_prom
regiones = df1.nombre_region

print_id = False # The shape id will be printed
color_pallete = 1 # 'Purples'
plot_regiones_data(sf, 'Valores de los vehículos en venta por regiones (datos Yapo.cl)', regiones, data, color_pallete, print_id)
# Out:
# 1: 2964864 => 4329473
# 2: 4329474 => 5489791
# 3: 5489792 => 5788004
# 4: 5788005 => 6595863
# 5: 6595864 => 6691715
# 6: 6691716 => 7935106
#
#    1   2   3   4   5   6

# %%
#!pip install descartes

# %%
import geopandas as gpd
df_geo = gpd.read_file(shp_path)
fig, ax = plt.subplots(figsize=(10,10))
df_geo.plot(ax=ax,color='white', edgecolor='black')
ax.set_aspect('equal')
plt.show()

# %%
df_geo
# Out:
#    ID_2002                                   NOMBRE  \
# 0       15                       Arica y Parinacota
# 1       01                                 Tarapaca
# 2       02                              Antofagasta
# 3       03                                  Atacama
# 4       04                                 Coquimbo
# 5       05                               Valparaiso
# 6       13                Metropolitana de Santiago
# 7       06      Libertador Gral. Bernardo O'Higgins
# 8       07                                    Maule
# 9       08                                   Biobio
# 10      09                             La Araucania
# 11      14                                 Los Rios
# 12      10                                Los Lagos
# 13      11  Aisen del Gral. Carlos Ibañez del Campo
# 14      12     Magallanes y de la Antartica Chileno
#
#                                              geometry
# 0   POLYGON ((-70.26623 -19.19022, -70.27196 -19.1...
# ...

# %%
df1
# Out:
#                               nombre_region  precio_prom
# 0                 Metropolitana de Santiago      7935107
# 1                              La Araucania      6788149
# 2                                Valparaiso      6714687
# 3                                  Los Rios      6645774
# 4      Magallanes y de la Antartica Chileno      6608490
# 5                               Antofagasta      6589551
# 6       Libertador Gral. Bernardo O'Higgins      5919774
# 7                                    Biobio      5788005
# 8                                 Los Lagos      5615220
# 9   Aisen del Gral. Carlos Ibañez del Campo      5613636
# 10                                 Coquimbo      5242105
# 11                                    Maule      4847155
# 12                                 Tarapaca      4070634
# 13                                  Atacama      3940000
# 14                       Arica y Parinacota      2964864

# %%
result = pd.concat([df_geo.set_index("NOMBRE"), df1.set_index("nombre_region")], axis=1, join='inner')
result
# Out:
#                                         ID_2002  \
# Arica y Parinacota                           15
# Tarapaca                                     01
# Antofagasta                                  02
# Atacama                                      03
# Coquimbo                                     04
# Valparaiso                                   05
# Metropolitana de Santiago                    13
# Libertador Gral. Bernardo O'Higgins          06
# Maule                                        07
# Biobio                                       08
# La Araucania                                 09
# Los Rios                                     14
# Los Lagos                                    10
# Aisen del Gral. Carlos Ibañez del Campo      11
# Magallanes y de la Antartica Chileno         12
#
#                                                                                   geometry  \
# Arica y Parinacota                       POLYGON ((-70.26623 -19.19022, -70.27196 -19.1...
# ...

# %%
import geopandas as gpd
df_geo = gpd.read_file(shp_path)
fig, ax = plt.subplots(figsize=(10,20))
result.plot(ax=ax,edgecolor='black',column='precio_prom', cmap='OrRd',legend=True,
        legend_kwds={'label': "Valor venta vehículos (datos Yapo.cl)",'orientation': "horizontal"})
ax.set_aspect('equal')
plt.show()

# %% [markdown]
# ## Pregunta 8.  10 Palabras mas frecuentes por Categoria

# %%
#!pip install spacy
#!python -m spacy download es_core_news_sm
# Out:
# ...
# ✔ Download and installation successful
# You can now load the model via spacy.load('es_core_news_sm')

# %%
import spacy
import pandas as pd
from collections import Counter
from pandas import DataFrame
nlp = spacy.load('es_core_news_sm')

spacy_stopwords = spacy.lang.es.stop_words.STOP_WORDS

# %%
sql = "select categoria, descripcion from anuncio order by categoria;"
cursor.execute(sql)
df4 = DataFrame(cursor.fetchall())
df4.columns = cursor.column_names
df4[1:]
# Out:
#                                 categoria  \
# 1      Accesorios y piezas para vehículos
# 2      Accesorios y piezas para vehículos
# 3      Accesorios y piezas para vehículos
# 4      Accesorios y piezas para vehículos
# 5      Accesorios y piezas para vehículos
# ...                                   ...
# 24662       Vestuario futura mamá y niños
# 24663       Vestuario futura mamá y niños
# 24664       Vestuario futura mamá y niños
# 24665       Vestuario futura mamá y niños
# 24666       Vestuario futura mamá y niños
#
#                                              descripcion
# 1      de neumáticos nuevos en Alto hospicioen liquid...
# 2      en Alto Hospicioventa de diferentes números de...
# 3      en Alto Hospicioventa de diferentes números de...
# 4      en liquidación en Alto hospicio de matemáticos...
# 5      en liquidación en Alto hospicio de matemáticos...
# ...                                                  ...
# ...

# %%
def tokenizer(description):
    doc = nlp(description)
    words = [token.text for token in doc  if  token.pos_ == 'ADJ' or token.pos_ == 'NOUN' or token.pos_ == 'NOUN' or token.pos_ == 'VERB']
    return words

# %%
words_Accesorios_y_piezas_para_vehiculos = []
words_Animales_y_sus_accesorios = []
words_Arriendo = []
words_Arte_antigüedades_y_colecciones = []
words_Audio_TV_video_y_fotografia = []
words_Autos_camionetas_y_4x4 = []
words_Barcos_lanchas_aviones = []
words_Bicicletas_ciclismo_accesorios = []
words_Bolsos_bisuteria_accesorios = []
words_Busco_empleo = []
words_Buses_camiones_furgones = []
words_Calzado = []
words_Celulares_teléfonos_accesorios = []
words_Coches_artículos_infantiles = []
words_Computadores_accesorios = []
words_Consolas_videojuegos_accesorios = []
words_Deportes_gimnasia_accesorios = []
words_Electrodomésticos = []
words_Hobbies_outdoor = []
words_Instrumentos_musicales_accesorios = []
words_Jardín_herramientas_exteriores = []
words_Juguetes = []
words_Libros_revistas = []
words_Moda_vestuario =[]
words_Motos = []
words_Muebles = []
words_Música_películas = []
words_Negocios_maquinaria_construcción = []
words_Ofertas_de_empleo = []
words_Otros_artículos_del_hogar = []
words_Otros_productos = []
words_Otros_vehículos = []
words_Salud_belleza = []
words_Servicios = []
words_Vendo =[]
words_Vestuario_futura_mamá_niños = []

for index, row in df4.iterrows():
    cat = row[0]
    des = row[1]
    if cat == 'Accesorios y piezas para vehículos':
        words_Accesorios_y_piezas_para_vehiculos += tokenizer(des)
    elif cat == 'Animales y sus accesorios':
        words_Animales_y_sus_accesorios += tokenizer(des)
    elif cat =='Arriendo' in cat:
        words_Arriendo += tokenizer(des)
    elif cat == 'Arte, antigüedades y colecciones':
        words_Arte_antigüedades_y_colecciones += tokenizer(des)
    elif cat == 'Audio, TV, video y fotografía':
        words_Audio_TV_video_y_fotografia += tokenizer(des)
    elif cat == 'Autos, camionetas y 4x4':
        words_Autos_camionetas_y_4x4 += tokenizer(des)
    elif cat == 'Barcos, lanchas y aviones':
        words_Barcos_lanchas_aviones += tokenizer(des)
    elif cat == 'Bicicletas, ciclismo y accesorios':
        words_Bicicletas_ciclismo_accesorios += tokenizer(des)
    elif cat == 'Bolsos, bisutería y accesorios':
        words_Bolsos_bisuteria_accesorios += tokenizer(des)
    elif cat == 'Busco empleo':
        words_Busco_empleo += tokenizer(des)
    elif cat == 'Buses, camiones y furgones':
        words_Buses_camiones_furgones += tokenizer(des)
    elif cat == 'Calzado':
        words_Calzado += tokenizer(des)
    elif cat == 'Celulares, teléfonos y accesorios':
        words_Celulares_teléfonos_accesorios += tokenizer(des)
    elif cat == 'Coches y artículos infantiles':
        words_Coches_artículos_infantiles += tokenizer(des)
    elif cat == 'Computadores y accesorios':
        words_Computadores_accesorios += tokenizer(des)
    elif cat == 'Consolas, videojuegos y accesorios':
        words_Consolas_videojuegos_accesorios +=  tokenizer(des)
    elif cat == 'Deportes, gimnasia y accesorios':
        words_Deportes_gimnasia_accesorios +=  tokenizer(des)
    elif cat == 'Electrodomésticos':
        words_Electrodomésticos += tokenizer(des)
    elif cat == 'Hobbies y outdoor':
        words_Hobbies_outdoor +=  tokenizer(des)
    elif cat == 'Instrumentos musicales y accesorios':
        words_Instrumentos_musicales_accesorios += tokenizer(des)
    elif cat == 'Jardín, herramientas y exteriores':
        words_Jardín_herramientas_exteriores += tokenizer(des)
    elif cat == 'Juguetes':
        words_Juguetes += tokenizer(des)
    elif cat == 'Libros y revistas':
        words_Libros_revistas += tokenizer(des)
    elif cat == 'Moda y vestuario':
        words_Moda_vestuario += tokenizer(des)
    elif cat == 'Motos':
        words_Motos += tokenizer(des)
    elif cat == 'Muebles':
        words_Muebles +=  tokenizer(des)
    elif cat == 'Música y películas (DVDs, etc.)':
        words_Música_películas += tokenizer(des)
    elif cat == 'Negocios, maquinaria y construcción':
        words_Negocios_maquinaria_construcción += tokenizer(des)
    elif cat == 'Ofertas de empleo':
        words_Ofertas_de_empleo += tokenizer(des)
    elif cat == 'Otros artículos del hogar':
        words_Otros_artículos_del_hogar += tokenizer(des)
    elif cat == 'Otros vehículos':
        words_Otros_vehículos += tokenizer(des)
    elif cat == 'Salud y belleza':
        words_Salud_belleza += tokenizer(des)
    elif cat == 'Servicios':
        words_Servicios += tokenizer(des)
    elif 'Vendo' in cat:
        words_Vendo += tokenizer(des)
    elif cat == 'Vestuario futura mamá y niños':
        words_Vestuario_futura_mamá_niños += tokenizer(des)
    else: # Otros productos
        words_Otros_productos += tokenizer(des)

# %%
print(words_Accesorios_y_piezas_para_vehiculos)
# Out:
# ['neumáticos', 'nuevos', 'liquidación', 'montaje', 'neumáticos', 'nuevos', 'liquidación', 'montaje', 'números', 'neumáticos', 'automóvil', 'Marcas', 'montaje', 'balanceo', 'gratuito', 'números', 'neumáticos', 'automóvil', 'Marcas', 'montaje', 'balanceo', 'gratuito', 'liquidación', 'hospicio', 'matemáticos', 'nuevos', 'montaje', 'balanceo', 'incluido', 'liquidación', 'hospicio', 'matemáticos', 'nuevos', 'montaje', 'balanceo', 'incluido', 'números', 'neumáticos', 'automóvil', 'Marcas', 'montaje', 'balanceo', 'gratuito', 'números', 'neumáticos', 'automóvil', 'Marcas', 'montaje', 'balanceo', 'gratuito', 'conversable', 'consultas', '948554997', 'conversable', 'consultas', '948554997', 'unidad', 'unidad', 'unidad', 'unidad', 'unidad', 'cajas', 'transmisión', '4x4', 'cambio', 'soporte', 'Precio', 'conversable', 'cajas', 'transmisión', '4x4', 'cambio', 'soporte', 'Precio', 'conversable', 'cajas', 'transmisión', '4x4', 'cambio', 'soporte', 'Precio', 'conversable', 'descenso', 'descenso', 'ven
# ...

# %%
len(words_Accesorios_y_piezas_para_vehiculos)
# Out:
# 16528

# %%
def counter_words(list_of_words):
    word_freq = Counter(list_of_words)
    common_words = word_freq.most_common(10)
    return common_words

# %%
lista_de_listas =[
    words_Accesorios_y_piezas_para_vehiculos,
    words_Animales_y_sus_accesorios,
    words_Arriendo,
    words_Arte_antigüedades_y_colecciones,
    words_Audio_TV_video_y_fotografia,
    words_Autos_camionetas_y_4x4,        
    words_Barcos_lanchas_aviones,
    words_Bicicletas_ciclismo_accesorios,
    words_Bolsos_bisuteria_accesorios,
    words_Busco_empleo,
    words_Buses_camiones_furgones,
    words_Calzado,
    words_Celulares_teléfonos_accesorios,
    words_Coches_artículos_infantiles,
    words_Computadores_accesorios,
    words_Consolas_videojuegos_accesorios,
    words_Deportes_gimnasia_accesorios,
    words_Electrodomésticos,
    words_Hobbies_outdoor,
    words_Instrumentos_musicales_accesorios,
    words_Jardín_herramientas_exteriores,
    words_Juguetes,
    words_Libros_revistas,
    words_Moda_vestuario ,
    words_Motos ,
    words_Muebles,
    words_Música_películas ,
    words_Negocios_maquinaria_construcción,
    words_Ofertas_de_empleo,
    words_Otros_artículos_del_hogar,
    words_Otros_productos,
    words_Otros_vehículos,
    words_Salud_belleza,
    words_Servicios,
    words_Vendo,
    words_Vestuario_futura_mamá_niños, 
]

# %%
list_of_names =[
        'Accesorios y piezas para vehículos',
    'Animales y sus accesorios',
    'Arriendo',
    'Arte, antigüedades y colecciones',
    'Audio, TV, video y fotografía',
    'Autos, camionetas y 4x4',        
    'Barcos_lanchas_aviones',
    'Bicicletas_ciclismo_accesorios',
    'Bolsos_bisutería_accesorios',
    'Busco_empleo',
    'Buses_camiones_furgones',
    'Calzado',
    'Celulares_teléfonos_accesorios',
    'Coches_artículos_infantiles',
    'Computadores_accesorios',
    'Consolas_videojuegos_accesorios',
    'Deportes_gimnasia_accesorios',
    'Electrodomésticos',
    'Hobbies_outdoor',
    'Instrumentos_musicales_accesorios',
    'Jardín_herramientas_exteriores',
    'Juguetes',
    'Libros_revistas',
    'Moda_vestuario' ,
    'Motos' ,
    'Muebles',
    'Música_películas' ,
    'Negocios_maquinaria_construcción',
    'Ofertas_de_empleo',
    'Otros_artículos_del_hogar',
    'Otros_productos',
    'Otros_vehículos',
    'Salud_belleza',
    'Servicios',
    'Vendo',
    'Vestuario_futura_mamá_niños',
]

# %%
for index in range(0,len(lista_de_listas)):
    
    print("Las 10 palabras mas frecuentes para la categoria: " + list_of_names[index])
    print(counter_words(lista_de_listas[index]))
    print(" ")
# Out:
# Las 10 palabras mas frecuentes para la categoria: Accesorios y piezas para vehículos
# [('DESARMADURIA', 561), ('DESPACHAMOS', 559), ('ACEPTAMOS', 559), ('DIRECCIÓN', 559), ('AUTOREY', 559), ('LTDA', 559), ('local', 255), ('estado', 188), ('establecido', 165), ('fotos', 163)]
#
# Las 10 palabras mas frecuentes para la categoria: Animales y sus accesorios
# [('perros', 28), ('meses', 26), ('uso', 24), ('raza', 24), ('local', 22), ('pareja', 21), ('ancho', 21), ('vende', 19), ('nivel', 19), ('tiempo', 19)]
#
# Las 10 palabras mas frecuentes para la categoria: Arriendo
# []
#
# Las 10 palabras mas frecuentes para la categoria: Arte, antigüedades y colecciones
# [('artista', 111), ('cuenta', 82), ('cuadros', 74), ('artistas', 74), ('mm', 39), ('punturas', 38), ('pintor', 35), ('aprox', 34), ('pinturas', 34), ('naval', 33)]
#
# Las 10 palabras mas frecuentes para la categoria: Audio, TV, video y fotografía
# ...

# %% [markdown]
# ## Pregunta 9.  10 Palabras mas frecuentes por Región

# %%
sql = "SELECT nombre_region, descripcion FROM vendedor JOIN anuncio USING(id_vendedor)"
cursor.execute(sql)
df5 = DataFrame(cursor.fetchall())
df5.columns = cursor.column_names
df5
# Out:
#             nombre_region                                        descripcion
# 0           Metropolitana  DE INSTALACIONES SANITARIAS:Servicios en:Proye...
# 1           Metropolitana  de Perrito reversible. Se transforma en su pro...
# 2           Metropolitana  de Perrito reversible. Se transforma en su pro...
# 3           Metropolitana  polar especial de montaña marca Katmandú. Tall...
# 4           Metropolitana  polar especial de montaña marca Katmandú. Tall...
# ...                   ...                                                ...
# 24662  Arica & Parinacota  Integrado modelo SANSUI AU-717, numero de seri...
# 24663  Arica & Parinacota  Parlantes (Speakers) marca SLIPSCH RB35 CHERRY...
# 24664  Arica & Parinacota  Parlantes (Speakers) marca SLIPSCH RB35 CHERRY...
# 24665  Arica & Parinacota  Reproductor de DVD/CD marca DENON 3910 (USADO)...
# 24666  Arica & Parinacota  Reproductor de DVD/CD marca DENON 3910 (USADO)...
#
# [24667 rows x 2 columns]

# %%
df5.nombre_region
# Out:
# 0             Metropolitana
# 1             Metropolitana
# 2             Metropolitana
# 3             Metropolitana
# 4             Metropolitana
#                 ...
# 24662    Arica & Parinacota
# 24663    Arica & Parinacota
# 24664    Arica & Parinacota
# 24665    Arica & Parinacota
# 24666    Arica & Parinacota
# Name: nombre_region, Length: 24667, dtype: object

# %%
words_Aisen = []
words_Antofagasta = []
words_Araucania = []
words_Arica_y_parinacota = []
words_Atacama = []
words_Biobio = []
words_Coquimbo = []
words_Los_lagos = []
words_Los_rios = []
words_Magallanes_y_Antartica = []
words_Maule = []
words_Metropolitana = []
words_Ñuble = []
words_Ohiggins = []
words_Tarapaca = []
words_Valparaiso = []

# %%
for index, row in df5.iterrows():
    cat = row[0]
    des = row[1]
    if cat == 'Aisén':
        words_Aisen += tokenizer(des)
    elif cat == 'Biobío':
        words_Biobio += tokenizer(des)
    elif cat == 'Magallanes & Antártica':
        words_Magallanes_y_Antartica += tokenizer(des)
    elif cat == 'Tarapacá':
        words_Tarapaca += tokenizer(des)
    elif cat == 'Valparaíso':
        words_Valparaiso += tokenizer(des)
    elif cat == 'Los Ríos':
        words_Los_rios += tokenizer(des)
    elif cat == 'Metropolitana':
        words_Metropolitana += tokenizer(des)
    elif cat == 'Coquimbo':
        words_Coquimbo += tokenizer(des)
    elif cat == 'Los Lagos':
        words_Los_lagos += tokenizer(des)
    elif cat == 'Araucanía':
        words_Araucania += tokenizer(des)
    elif cat == "O'Higgins":
        words_Ohiggins += tokenizer(des)
    elif cat == 'Arica & Parinacota':
        words_Arica_y_parinacota += tokenizer(des)
    elif cat == 'Antofagasta':
        words_Antofagasta += tokenizer(des)
    elif cat == 'Ñuble':
        words_Ñuble += tokenizer(des)
    elif cat == 'Maule':
        words_Maule +=  tokenizer(des)
    elif cat == 'Atacama':
        words_Atacama +=  tokenizer(des)

# %%
print(words_Los_rios)
# Out:
# ['portabicicletas', 'rueda', 'trasera', 'repuesto', 'ideal', 'entren', 'bicicletas', 'ofertas', 'precios', 'razonables', 'duda', 'portabicicletas', 'rueda', 'trasera', 'repuesto', 'ideal', 'entren', 'bicicletas', 'ofertas', 'precios', 'razonables', 'duda', '205.000.000.Terreno', '–', 'visita', 'habitación', 'servicio', 'independiente', 'amplia', 'ubicada', 'barrio', 'residencial', 'consolidado', 'Alta', 'conectividad', 'minutos', 'centro', 'cercana', 'supermercados', 'colegios', 'bomberos', 'hospital', 'Distribución', 'interior', 'Dormitorio', 'servicio', 'Pieza', 'Segundo', 'ser', 'lugar', 'amplio', 'utilizado', 'sala', 'alfombradas', 'piso', 'Cuenta', 'acceso', 'independiente', 'Cabañas', 'individuales', 'actualidad', 'arrendadas', 'ganancia', 'encuentra', 'precio', 'bajo', 'mercado', 'consolidado', 'tranquilo', 'superficies', 'características', 'entregadas', 'propiedad', 'son', 'aproximadas', 'referenciales', 'han', 'sido', 'proporcionadas', 'dueño', 'mayor', 'información', 'coord
# ...

# %%
lista_de_listas2 =[
    words_Aisen,
    words_Antofagasta,
    words_Araucania,
    words_Arica_y_parinacota,
    words_Atacama,
    words_Biobio,
    words_Coquimbo,
    words_Los_lagos,
    words_Los_rios,
    words_Magallanes_y_Antartica,
    words_Maule,
    words_Metropolitana,
    words_Ñuble,
    words_Ohiggins,
    words_Tarapaca,
    words_Valparaiso,
]

# %%
list_of_names2 =[
        'Aisén',
    'Antofagasta',
    'Araucanía',
    'Arica & Parinacota',
    'Atacama',
    'Biobío',        
    'Coquimbo',
    'Los Lagos',
    'Los Ríos',
    'Magallanes & Antártica',
    'Maule',
    'Metropolitana',
    'Ñuble',
    "O'Higgins",
    'Tarapacá',
    'Valparaíso',
]

# %%
for index in range(0,len(lista_de_listas2)):
    
    print("Las 10 palabras mas frecuentes para la categoria: " + list_of_names2[index])
    print(counter_words(lista_de_listas2[index]))
    print(" ")
# Out:
# Las 10 palabras mas frecuentes para la categoria: Aisén
# [('vende', 35), ('uso', 25), ('día', 23), ('estado', 21), ('conversable', 17), ('vendo', 17), ('casa', 16), ('buen', 15), ('zona', 13), ('franca', 13)]
#
# Las 10 palabras mas frecuentes para la categoria: Antofagasta
# [('uso', 136), ('vende', 117), ('estado', 97), ('valor', 88), ('cocina', 74), ('buen', 70), ('cuenta', 69), ('arriendo', 64), ('casa', 62), ('living', 56)]
#
# Las 10 palabras mas frecuentes para la categoria: Araucanía
# [('estado', 181), ('vende', 176), ('uso', 130), ('conversable', 121), ('buen', 96), ('excelente', 91), ('nuevo', 88), ('precio', 77), ('día', 77), ('tiene', 59)]
#
# Las 10 palabras mas frecuentes para la categoria: Arica & Parinacota
# [('estado', 28), ('excelente', 27), ('día', 22), ('condiciones', 19), ('buen', 18), ('vende', 16), ('terraza', 15), ('baño', 15), ('domicilio', 14), ('papeles', 14)]
#
# Las 10 palabras mas frecuentes para la categoria: Atacama
# ...

# %% [markdown]
# ## Pregunta 10.

# %% [markdown]
# En el contexto de la pandemia, seria interesante analizar como aumentaron la cantidad de anuncios en diversas categorias y sus respectivos precios, pero por lo visto la base de datos que se pueden construir no son muy extensas en tiempo, además los anuncios en yapo de por sí no suelen durar mucho tiempo, por lo que no se pueden ver fácilmente anuncios de forma histórica en el pasado, por lo que haciendo uso del scraping de datos habría que estar constantemente armando bases de datos de yapo.cl a lo largo del tiempo e ir comparando esas bases de datos entre ellas.
#
# Ahora algo más que se puede analizar tiene que ver con el tema del 10%, es algo que esta ocurriendo en este mismo instante y es algo que puede ser más fácil de visualizar en la base de datos generada estos días.
#
# Sería interesante ver como ha cambiado la cantidad y variedad de anuncios en las categorias correspondientes a los vehículos, muebles, electronica, y materiales de construcción respectivamente, lo que nos permitiría observar como el retiro del 10% de las AFP afectó a la economía doméstica chilena, así podemos analizar que fue lo que se vendió más, que tipo de productos y si realmente hubo una diferencia entre antes y despues del retiro de dinero de los fondos de pensiones.
